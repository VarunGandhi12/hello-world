# %%
print("Name: Varun Gandhi, USN:22BTRCL164, AIML secB, Group-C,")
print(" Day 1 Health care project")
# Out:
# Name: Varun Gandhi, USN:22BTRCL164, AIML secB, Group-C,
#  Day 1 Health care project

# %%
# prompt: use andas to display the census 2011 csv file

import pandas as pd

# Read the CSV file
df = pd.read_csv('/content/census_2011.csv')

# Display the DataFrame
display(df)
# Out:
#      District code                   State name              District name  \
# 0                1            JAMMU AND KASHMIR                    Kupwara
# 1                2            JAMMU AND KASHMIR                     Badgam
# 2                3            JAMMU AND KASHMIR                Leh(Ladakh)
# 3                4            JAMMU AND KASHMIR                     Kargil
# 4                5            JAMMU AND KASHMIR                      Punch
# ..             ...                          ...                        ...
# 635            636                  PONDICHERRY                       Mahe
# 636            637                  PONDICHERRY                   Karaikal
# 637            638  ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 638            639  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 639            640  ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
# ...

# %% [markdown]
# Problem statment 1

# %%
selected_columns = [
    'State name',
    'District name',
    'Population',
    'Male',
    'Female',
    'Literate',
    'Male_Literate',
    'Female_Literate',
    'Rural_Households',
    'Urban_Households',
    'Households',
    'Age_Group_0_29',
    'Age_Group_30_49',
    'Age_Group_50',
    'Age not stated'
]

# Create a new DataFrame with only the selected columns
selected_df = df[selected_columns]

# Optionally, you can save this DataFrame to a new CSV file
selected_df.to_csv('selected_data.csv', index=False)
display(selected_df)
# Out:
#                       State name              District name  Population  \
# 0              JAMMU AND KASHMIR                    Kupwara    870354.0
# 1              JAMMU AND KASHMIR                     Badgam    753745.0
# 2              JAMMU AND KASHMIR                Leh(Ladakh)    133487.0
# 3              JAMMU AND KASHMIR                     Kargil    140802.0
# 4              JAMMU AND KASHMIR                      Punch         NaN
# ..                           ...                        ...         ...
# 635                  PONDICHERRY                       Mahe     41816.0
# 636                  PONDICHERRY                   Karaikal    200222.0
# 637  ANDAMAN AND NICOBAR ISLANDS                   Nicobars     36842.0
# 638  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman    105597.0
# 639  ANDAMAN AND NICOBAR ISLANDS              South Andaman         NaN
#
#          Male    Female  Literate  Male_Literate  Female_Literate  \
# ...

# %% [markdown]
# Problem statment 2

# %%
# Select only the columns you need
selected_columns = [
    'State name',
    'District name',
    'Population',
    'Male',
    'Female',
    'Literate',
    'Male_Literate',
    'Female_Literate',
    'Rural_Households',
    'Urban_Households',
    'Households',
    'Age_Group_0_29',
    'Age_Group_30_49',
    'Age_Group_50',
    'Age not stated'
]

# Create a new DataFrame with only the selected columns
selected_df = df[selected_columns]

# Rename columns for uniformity
selected_df = selected_df.rename(columns={
    'State name': 'State/UT',
    'District name': 'District',
    'Male_Literate': 'Literate_Male',
    'Female_Literate': 'Literate_Female',
    'Rural_Households': 'Households_Rural',
    'Urban_Households': 'Households_Urban',
    'Age_Group_0_29': 'Young_and_Adult',
    'Age_Group_30_49': 'Middle_Aged',
    'Age_Group_50': 'Senior_Citizen',
    'Age not stated': 'Age_Not_Stated'
})

# Optionally, you can save this DataFrame to a new CSV file
selected_df.to_csv('selected_data_uniform.csv', index=False)
display(selected_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 21
#       2 selected_columns = [
#       3     'State name',
#       4     'District name',
#    (...)
#      17     'Age not stated'
#      18 ]
#      20 # Create a new DataFrame with only the selected columns
# ---> 21 selected_df = df[selected_columns]
#      23 # Rename columns for uniformity
#      24 selected_df = selected_df.rename(columns={
#      25     'State name': 'State/UT',
#      26     'District name': 'District',
#    (...)
#      34     'Age not stated': 'Age_Not_Stated'
#      35 })
#
# NameError: name 'df' is not defined

# %% [markdown]
# Problem statment 3

# %%
# Create a dictionary to map the original state/UT names to the desired format
state_name_mapping = {
    "Andaman and Nicobar Islands": "Andaman and nicobar islands",
    "Arunachal Pradesh": "Arunachal pradesh",
    "Bihar": "Bihar",
    # ... add other state/UT mappings here ...
}

# Use the dictionary to rename the states/UTs in the DataFrame
selected_df['State/UT'] = selected_df['State/UT'].map(state_name_mapping)

# Display the updated DataFrame
display(selected_df)
# Out:
#     State/UT                   District  Population      Male    Female  \
# 0        NaN                    Kupwara    870354.0  474190.0  396164.0
# 1        NaN                     Badgam    753745.0       NaN  355704.0
# 2        NaN                Leh(Ladakh)    133487.0   78971.0   54516.0
# 3        NaN                     Kargil    140802.0       NaN   63017.0
# 4        NaN                      Punch         NaN  251899.0  224936.0
# ..       ...                        ...         ...       ...       ...
# 635      NaN                       Mahe     41816.0   19143.0   22673.0
# 636      NaN                   Karaikal    200222.0   97809.0  102413.0
# 637      NaN                   Nicobars     36842.0   20727.0       NaN
# 638      NaN  North  AND Middle Andaman    105597.0   54861.0   50736.0
# 639      NaN              South Andaman         NaN  127283.0  110859.0
#
#      Literate  Literate_Male  Literate_Female  Households_Rural  \
# ...

# %% [markdown]
# problem statment 4

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = selected_df

# Read the districts included in Telangana from the text file
with open('/content/Telangana.txt', 'r') as file:
    telangana_districts = [line.strip() for line in file]

# Rename State/UT from "Andhra Pradesh" to "Telangana" for the given districts
df.loc[df['District'].isin(telangana_districts), 'State/UT'] = 'Telangana'

# Optionally, you can save the modified DataFrame to a new CSV file
df.to_csv('updated_dataset.csv', index=False)
updated_df = pd.read_csv('updated_dataset.csv')

# Display the updated DataFrame
display(updated_df)
# Out:
#     State/UT                   District  Population      Male    Female  \
# 0        NaN                    Kupwara    870354.0  474190.0  396164.0
# 1        NaN                     Badgam    753745.0       NaN  355704.0
# 2        NaN                Leh(Ladakh)    133487.0   78971.0   54516.0
# 3        NaN                     Kargil    140802.0       NaN   63017.0
# 4        NaN                      Punch         NaN  251899.0  224936.0
# ..       ...                        ...         ...       ...       ...
# 635      NaN                       Mahe     41816.0   19143.0   22673.0
# 636      NaN                   Karaikal    200222.0   97809.0  102413.0
# 637      NaN                   Nicobars     36842.0   20727.0       NaN
# 638      NaN  North  AND Middle Andaman    105597.0   54861.0   50736.0
# 639      NaN              South Andaman         NaN  127283.0  110859.0
#
#      Literate  Literate_Male  Literate_Female  Households_Rural  \
# ...
